# %%
import boto3

# %%
account_id = boto3.client("sts").get_caller_identity().get("Account")
region = boto3.Session().region_name
ecr_repository = "hemz_agents_repo"
tag = ":latest"
processing_repository_uri = "{}.dkr.ecr.{}.amazonaws.com/{}".format(
    account_id, region, ecr_repository + tag
)

# %%
# Login to ECR
# !aws ecr get-login-password --region {region} | docker login --username AWS --password-stdin {account_id}.dkr.ecr.{region}.amazonaws.com
# Out:
# Login Succeeded

# %%
# Create ECR repository
# !aws ecr create-repository --repository-name $ecr_repository --region {region}
# Out:
# {
#     "repository": {
#         "repositoryArn": "arn:aws:ecr:us-east-1:792560738609:repository/hemz_agents_repo",
#         "registryId": "792560738609",
#         "repositoryName": "hemz_agents_repo",
#         "repositoryUri": "792560738609.dkr.ecr.us-east-1.amazonaws.com/hemz_agents_repo",
#         "createdAt": "2025-11-04T18:26:17.428000+05:30",
#         "imageTagMutability": "MUTABLE",
#         "imageScanningConfiguration": {
#             "scanOnPush": false
#         },
#         "encryptionConfiguration": {
#             "encryptionType": "AES256"
#         }
#     }
# }

# %%
# build and tag docker image
# !docker build -t {processing_repository_uri} ../../
# !docker build --platform linux/arm64 -t {processing_repository_uri} ../
# Out:
# #0 building with "desktop-linux" instance using docker driver
#
# #1 [internal] load build definition from Dockerfile
# #1 transferring dockerfile: 473B 0.0s done
# #1 DONE 0.1s
#
# #2 [internal] load metadata for ghcr.io/astral-sh/uv:python3.12-bookworm-slim
# #2 DONE 3.0s
#
# #3 [internal] load .dockerignore
# #3 transferring context: 714B 0.0s done
# #3 DONE 0.0s
#
# #4 [internal] load build context
# #4 transferring context: 7.32kB 0.0s done
# #4 DONE 0.1s
#
# #5 [1/6] FROM ghcr.io/astral-sh/uv:python3.12-bookworm-slim@sha256:4f52717de41541452f5318571b05da783d2ddf346a94b4d5c6512a4b51e986bd
# #5 resolve ghcr.io/astral-sh/uv:python3.12-bookworm-slim@sha256:4f52717de41541452f5318571b05da783d2ddf346a94b4d5c6512a4b51e986bd 0.1s done
# #5 DONE 0.1s
#
# #6 [2/6] WORKDIR /workspace
# #6 CACHED
#
# #7 [3/6] COPY pyproject.toml uv.lock ./
# #7 CACHED
#
# #8 [4/6] RUN uv sync --frozen --no-cache
# #8 CACHED
#
# #9 [5/6] COPY app/ ./app/
# #9 DONE 0.1s
#
# #10 [6/6] COPY .env ./
# #10 DONE 0.1s
#
# #11 exporting to image
# #11 exporting layers
# #11 exporting layers 0.2s done
# #11 exporting manifest sha256:4ce3d249c537ad1078558ed9097e1a81144e69952897cbb9c71422af712ef30e 0.0s done
# #11 exporting config sha256:50dc54bb1b893e7727094089c6f2b76ead25e3bf47090dd028b8e691224b62f9 0.0s done
# #11 exporting attestation manifest sha256:e5d208d609f5e9b2e2ba0b65c91fa69484cda2c1fe07ae19aa77dcc0a2f029b8 0.1s done
# #11 exporting manifest list sha256:e7196c431264bf02d402f8f01e33e4cf2d87b8c8da2a75d45224d9347b018d60
# #11 exporting manifest list sha256:e7196c431264bf02d402f8f01e33e4cf2d87b8c8da2a75d45224d9347b018d60 0.0s done
# #11 naming to 792560738609.dkr.ecr.us-east-1.amazonaws.com/hemz_agents_repo:latest done
# #11 DONE 0.5s
#
# View build details: docker-desktop://dashboard/build/desktop-linux/desktop-linux/hd1l1u74dxamgfjl0268x3wrn

# %%
# push the image to repository
# !docker push $processing_repository_uri
# Out:
# The push refers to repository [792560738609.dkr.ecr.us-east-1.amazonaws.com/hemz_agents_repo]
# d83521b2ff92: Waiting
# 97cdf303dd97: Waiting
# 4e268f2242be: Waiting
# 21b7accdc53f: Waiting
# b34e631a6ef2: Waiting
# 41fa5e086f31: Waiting
# 5ae4bd10d370: Waiting
# e773b80e62e3: Waiting
# 3d410fb3ba62: Waiting
# 7e2977d16f73: Waiting
# f0848f197f70: Waiting
# d83521b2ff92: Waiting
# 97cdf303dd97: Waiting
# 4e268f2242be: Waiting
# 21b7accdc53f: Waiting
# b34e631a6ef2: Waiting
# 41fa5e086f31: Waiting
# 5ae4bd10d370: Waiting
# e773b80e62e3: Waiting
# 3d410fb3ba62: Waiting
# 7e2977d16f73: Waiting
# f0848f197f70: Waiting
# e773b80e62e3: Waiting
# 3d410fb3ba62: Waiting
# 7e2977d16f73: Waiting
# f0848f197f70: Waiting
# d83521b2ff92: Waiting
# 97cdf303dd97: Waiting
# 4e268f2242be: Waiting
# 21b7accdc53f: Waiting
# b34e631a6ef2: Waiting
# 41fa5e086f31: Waiting
# 5ae4bd10d370: Waiting
# 3d410fb3ba62: Waiting
# 7e2977d16f73: Waiting
# f0848f197f70: Waiting
# d83521b2ff92: Waiting
# 97cdf303dd97: Waiting
# 4e268f2242be: Waiting
# 21b7accdc53f: Waiting
# b34e631a6ef2: Waiting
# 41fa5e086f31: Waiting
# 5ae4bd10d370: Waiting
# e773b80e62e3: Waiting
# 21b7accdc53f: Waiting
# b34e631a6ef2: Waiting
# 41fa5e086f31: Waiting
# 5ae4bd10d370: Waiting
# e773b80e62e3: Waiting
# 3d410fb3ba62: Waiting
# 7e2977d16f73: Waiting
# f0848f197f70: Waiting
# d83521b2ff92: Waiting
# 97cdf303dd97: Waiting
# 4e268f2242be: Waiting
# 41fa5e086f31: Waiting
# 5ae4bd10d370: Waiting
# e773b80e62e3: Waiting
# 3d410fb3ba62: Waiting
# 7e2977d16f73: Waiting
# f0848f197f70: Waiting
# d83521b2ff92: Waiting
# 97cdf303dd97: Waiting
# 4e268f2242be: Waiting
# 21b7accdc53f: Waiting
# b34e631a6ef2: Waiting
# b34e631a6ef2: Waiting
# 41fa5e086f31: Waiting
# 5ae4bd10d370: Waiting
# e773b80e62e3: Waiting
# 3d410fb3ba62: Waiting
# 7e2977d16f73: Waiting
# f0848f197f70: Waiting
# d83521b2ff92: Waiting
# 97cdf303dd97: Waiting
# 4e268f2242be: Waiting
# 21b7accdc53f: Waiting
# e773b80e62e3: Waiting
# 3d410fb3ba62: Waiting
# 7e2977d16f73: Waiting
# f0848f197f70: Waiting
# d83521b2ff92: Waiting
# 97cdf303dd97: Waiting
# 4e268f2242be: Waiting
# 21b7accdc53f: Waiting
# b34e631a6ef2: Waiting
# 41fa5e086f31: Waiting
# 5ae4bd10d370: Waiting
# b34e631a6ef2: Waiting
# 41fa5e086f31: Waiting
# 5ae4bd10d370: Waiting
# e773b80e62e3: Waiting
# 3d410fb3ba62: Waiting
# 7e2977d16f73: Waiting
# f0848f197f70: Waiting
# d83521b2ff92: Waiting
# 97cdf303dd97: Waiting
# 4e268f2242be: Waiting
# 21b7accdc53f: Waiting
# e773b80e62e3: Waiting
# 3d410fb3ba62: Waiting
# 7e2977d16f73: Waiting
# f0848f197f70: Waiting
# d83521b2ff92: Waiting
# 97cdf303dd97: Waiting
# 4e268f2242be: Waiting
# 21b7accdc53f: Waiting
# b34e631a6ef2: Waiting
# 41fa5e086f31: Waiting
# 5ae4bd10d370: Waiting
# d83521b2ff92: Waiting
# 97cdf303dd97: Waiting
# 4e268f2242be: Waiting
# 21b7accdc53f: Waiting
# b34e631a6ef2: Waiting
# 41fa5e086f31: Waiting
# 5ae4bd10d370: Waiting
# e773b80e62e3: Waiting
# 3d410fb3ba62: Waiting
# 7e2977d16f73: Waiting
# f0848f197f70: Waiting
# 5ae4bd10d370: Waiting
# e773b80e62e3: Waiting
# 3d410fb3ba62: Waiting
# 7e2977d16f73: Waiting
# f0848f197f70: Waiting
# d83521b2ff92: Waiting
# 97cdf303dd97: Waiting
# 4e268f2242be: Waiting
# 21b7accdc53f: Waiting
# b34e631a6ef2: Waiting
# 41fa5e086f31: Waiting
# f0848f197f70: Waiting
# d83521b2ff92: Waiting
# 97cdf303dd97: Waiting
# 4e268f2242be: Waiting
# 21b7accdc53f: Waiting
# b34e631a6ef2: Waiting
# 41fa5e086f31: Waiting
# 5ae4bd10d370: Waiting
# e773b80e62e3: Waiting
# 3d410fb3ba62: Waiting
# 7e2977d16f73: Waiting
# 97cdf303dd97: Waiting
# 4e268f2242be: Waiting
# 21b7accdc53f: Waiting
# b34e631a6ef2: Waiting
# 41fa5e086f31: Waiting
# 5ae4bd10d370: Waiting
# e773b80e62e3: Waiting
# 3d410fb3ba62: Waiting
# 7e2977d16f73: Waiting
# f0848f197f70: Waiting
# d83521b2ff92: Waiting
# d83521b2ff92: Waiting
# 97cdf303dd97: Waiting
# 4e268f2242be: Waiting
# 21b7accdc53f: Waiting
# b34e631a6ef2: Waiting
# 41fa5e086f31: Waiting
# 5ae4bd10d370: Waiting
# e773b80e62e3: Waiting
# 3d410fb3ba62: Waiting
# 7e2977d16f73: Waiting
# f0848f197f70: Waiting
# d83521b2ff92: Waiting
# 97cdf303dd97: Waiting
# 4e268f2242be: Waiting
# 21b7accdc53f: Waiting
# b34e631a6ef2: Waiting
# 41fa5e086f31: Waiting
# 5ae4bd10d370: Waiting
# e773b80e62e3: Waiting
# 3d410fb3ba62: Waiting
# 7e2977d16f73: Waiting
# f0848f197f70: Waiting
# 5ae4bd10d370: Layer already exists
# e773b80e62e3: Layer already exists
# 3d410fb3ba62: Waiting
# 7e2977d16f73: Waiting
# f0848f197f70: Waiting
# d83521b2ff92: Waiting
# 97cdf303dd97: Waiting
# 4e268f2242be: Layer already exists
# 21b7accdc53f: Layer already exists
# b34e631a6ef2: Waiting
# 41fa5e086f31: Waiting
# 7e2977d16f73: Waiting
# f0848f197f70: Waiting
# d83521b2ff92: Waiting
# 97cdf303dd97: Waiting
# b34e631a6ef2: Waiting
# 41fa5e086f31: Waiting
# 3d410fb3ba62: Waiting
# 3d410fb3ba62: Waiting
# 7e2977d16f73: Waiting
# f0848f197f70: Waiting
# d83521b2ff92: Waiting
# 97cdf303dd97: Waiting
# b34e631a6ef2: Waiting
# 41fa5e086f31: Waiting
# 3d410fb3ba62: Waiting
# 7e2977d16f73: Waiting
# f0848f197f70: Waiting
# d83521b2ff92: Waiting
# 97cdf303dd97: Waiting
# b34e631a6ef2: Waiting
# 41fa5e086f31: Waiting
# d83521b2ff92: Waiting
# 97cdf303dd97: Waiting
# b34e631a6ef2: Waiting
# 41fa5e086f31: Waiting
# 3d410fb3ba62: Waiting
# 7e2977d16f73: Waiting
# f0848f197f70: Waiting
# b34e631a6ef2: Layer already exists
# 41fa5e086f31: Waiting
# 3d410fb3ba62: Layer already exists
# 7e2977d16f73: Layer already exists
# f0848f197f70: Layer already exists
# d83521b2ff92: Waiting
# 41fa5e086f31: Waiting
# d83521b2ff92: Waiting
# 41fa5e086f31: Waiting
# d83521b2ff92: Waiting
# d83521b2ff92: Waiting
# 41fa5e086f31: Waiting
# 97cdf303dd97: Pushed
# d83521b2ff92: Pushed
# 41fa5e086f31: Pushed
# latest: digest: sha256:e7196c431264bf02d402f8f01e33e4cf2d87b8c8da2a75d45224d9347b018d60 size: 856

# %%
# Verify the image
# !aws ecr describe-images --repository-name {ecr_repository} --region {region}
# Out:
# {
#     "imageDetails": [
#         {
#             "registryId": "792560738609",
#             "repositoryName": "hemz_agents_repo",
#             "imageDigest": "sha256:0679dfda5032ae58749ed712ac50bbfe8bb43d1b1a44f2f70ea667bdc2c431e1",
#             "imageSizeInBytes": 1429,
#             "imagePushedAt": "2025-11-04T18:27:33.056000+05:30",
#             "imageManifestMediaType": "application/vnd.oci.image.manifest.v1+json",
#             "artifactMediaType": "application/vnd.oci.image.config.v1+json"
#         },
#         {
#             "registryId": "792560738609",
#             "repositoryName": "hemz_agents_repo",
#             "imageDigest": "sha256:8d5a268ec1e957ef271fd2685485fa0b8ae03940dd42b1ff89af9426c5adb746",
#             "imageSizeInBytes": 371149304,
#             "imagePushedAt": "2025-11-04T18:27:32.561000+05:30",
#             "imageManifestMediaType": "application/vnd.oci.image.manifest.v1+json",
#             "artifactMediaType": "application/vnd.oci.image.config.v1+json"
#         },
#         {
#             "registryId": "792560738609",
#             "repositoryName": "hemz_agents_repo",
#             "imageDigest": "sha256:f8ef132cf4e7124ff549ae4497dc8b936be0cd520564b1dfe710c169b05c541f",
#             "imageTags": [
#                 "latest"
#             ],
#             "imageSizeInBytes": 371149304,
#             "imagePushedAt": "2025-11-04T18:27:33.865000+05:30",
#             "imageManifestMediaType": "application/vnd.oci.image.index.v1+json"
#         }
#     ]
# }
