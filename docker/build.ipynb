# %%
import boto3

# %%
account_id = boto3.client("sts").get_caller_identity().get("Account")
region = boto3.Session().region_name
ecr_repository = "hemz_agents_repo"
tag = ":latest"
processing_repository_uri = "{}.dkr.ecr.{}.amazonaws.com/{}".format(
    account_id, region, ecr_repository + tag
)

# %%
# Login to ECR
# !aws ecr get-login-password --region {region} | docker login --username AWS --password-stdin {account_id}.dkr.ecr.{region}.amazonaws.com
# Out:
# Login Succeeded

# %%
# Create ECR repository
# !aws ecr create-repository --repository-name $ecr_repository --region {region}

# %%
# build and tag docker image
# !docker build -t {processing_repository_uri} ../../
# !docker build --platform linux/arm64 -t {processing_repository_uri} ../
# Out:
# #0 building with "desktop-linux" instance using docker driver
#
# #1 [internal] load build definition from Dockerfile
# #1 transferring dockerfile: 432B 0.1s done
# #1 DONE 0.1s
#
# #2 [internal] load metadata for ghcr.io/astral-sh/uv:python3.12-bookworm-slim
# #2 DONE 2.6s
#
# #3 [internal] load .dockerignore
# #3 transferring context: 2B 0.0s done
# #3 DONE 0.1s
#
# #4 [internal] load build context
# #4 transferring context: 716.00kB 0.2s done
# #4 DONE 0.2s
#
# #5 [1/5] FROM ghcr.io/astral-sh/uv:python3.12-bookworm-slim@sha256:4f52717de41541452f5318571b05da783d2ddf346a94b4d5c6512a4b51e986bd
# #5 resolve ghcr.io/astral-sh/uv:python3.12-bookworm-slim@sha256:4f52717de41541452f5318571b05da783d2ddf346a94b4d5c6512a4b51e986bd 0.1s done
# #5 CACHED
#
# #6 [2/5] WORKDIR /workspace
# #6 DONE 0.1s
#
# #7 [3/5] COPY pyproject.toml uv.lock ./
# #7 DONE 0.2s
#
# #8 [4/5] RUN uv sync --frozen --no-cache
# #8 9.893 Using CPython 3.12.12 interpreter at: /usr/local/bin/python3
# #8 9.916 Creating virtual environment at: .venv
# #8 12.34 Downloading botocore (13.4MiB)
# #8 12.42 Downloading pip (1.7MiB)
# #8 12.46 Downloading grpcio (6.1MiB)
# #8 12.50 Downloading pypdfium2 (2.8MiB)
# #8 12.52 Downloading aiohttp (1.7MiB)
# #8 12.53 Downloading pyarrow (42.9MiB)
# #8 12.53 Downloading pydantic-core (1.9MiB)
# #8 12.54 Downloading hf-xet (3.1MiB)
# #8 12.55 Downloading tiktoken (1.1MiB)
# #8 12.55 Downloading pygments (1.2MiB)
# #8 12.58 Downloading pylance (43.0MiB)
# #8 12.58 Downloading numpy (13.6MiB)
# #8 12.59 Downloading cryptography (4.1MiB)
# #8 12.60 Downloading pdfminer-six (5.4MiB)
# #8 12.60 Downloading virtualenv (5.7MiB)
# #8 12.61 Downloading pillow (6.1MiB)
# #8 12.62 Downloading kubernetes (1.9MiB)
# #8 12.63 Downloading uv (19.3MiB)
# #8 12.63 Downloading uvloop (4.1MiB)
# #8 12.64 Downloading tokenizers (3.1MiB)
# #8 12.65 Downloading sympy (6.0MiB)
# #8 12.66 Downloading chromadb (18.0MiB)
# #8 12.67 Downloading lxml (4.8MiB)
# #8 12.68 Downloading litellm (9.8MiB)
# #8 12.70 Downloading onnxruntime (14.5MiB)
# #8 12.72 Downloading lancedb (33.4MiB)
# #8 29.14  Downloading tiktoken
# #8 35.40  Downloading aiohttp
# #8 35.53  Downloading pydantic-core
# #8 39.29    Building pypika==0.48.9
# #8 40.18  Downloading pygments
# #8 41.11  Downloading pypdfium2
# #8 43.39  Downloading hf-xet
# #8 43.50  Downloading tokenizers
# #8 46.40  Downloading pip
# #8 50.23  Downloading uvloop
# #8 50.97  Downloading cryptography
# #8 55.85  Downloading pdfminer-six
# #8 55.96  Downloading kubernetes
# #8 57.18  Downloading lxml
# #8 59.31  Downloading virtualenv
# #8 60.12  Downloading pillow
# #8 60.35  Downloading grpcio
# #8 77.96  Downloading numpy
# #8 78.74  Downloading sympy
# #8 83.35  Downloading chromadb
# #8 84.71  Downloading uv
# #8 95.47       Built pypika==0.48.9
# #8 97.04  Downloading lancedb
# #8 100.7  Downloading onnxruntime
# #8 100.8  Downloading pylance
# #8 101.1  Downloading litellm
# #8 101.4  Downloading botocore
# #8 102.1  Downloading pyarrow
# #8 102.1 Prepared 165 packages in 1m 31s
# #8 102.7 Installed 165 packages in 618ms
# #8 102.7  + aiohappyeyeballs==2.6.1
# #8 102.7  + aiohttp==3.13.2
# #8 102.7  + aiosignal==1.4.0
# #8 102.7  + annotated-doc==0.0.3
# #8 102.7  + annotated-types==0.7.0
# #8 102.7  + anyio==4.11.0
# #8 102.7  + appdirs==1.4.4
# #8 102.7  + attrs==25.4.0
# #8 102.7  + backoff==2.2.1
# #8 102.7  + bcrypt==5.0.0
# #8 102.7  + beautifulsoup4==4.14.2
# #8 102.7  + boto3==1.40.65
# #8 102.7  + botocore==1.40.65
# #8 102.7  + build==1.3.0
# #8 102.7  + cachetools==6.2.1
# #8 102.7  + certifi==2025.10.5
# #8 102.7  + cffi==2.0.0
# #8 102.7  + cfgv==3.4.0
# #8 102.7  + charset-normalizer==3.4.4
# #8 102.7  + chromadb==1.1.1
# #8 102.8  + click==8.3.0
# #8 102.8  + coloredlogs==15.0.1
# #8 102.8  + crewai==1.3.0
# #8 102.8  + crewai-tools==1.3.0
# #8 102.8  + cryptography==46.0.3
# #8 102.8  + defusedxml==0.7.1
# #8 102.8  + deprecation==2.1.0
# #8 102.8  + diskcache==5.6.3
# #8 102.8  + distlib==0.4.0
# #8 102.8  + distro==1.9.0
# #8 102.8  + docker==7.1.0
# #8 102.8  + docstring-parser==0.17.0
# #8 102.8  + durationpy==0.10
# #8 102.8  + et-xmlfile==2.0.0
# #8 102.8  + fastapi==0.121.0
# #8 102.8  + fastuuid==0.14.0
# #8 102.8  + filelock==3.20.0
# #8 102.8  + flatbuffers==25.9.23
# #8 102.8  + frozenlist==1.8.0
# #8 102.8  + fsspec==2025.10.0
# #8 102.8  + google-auth==2.42.1
# #8 102.8  + googleapis-common-protos==1.71.0
# #8 102.8  + grpcio==1.76.0
# #8 102.8  + h11==0.16.0
# #8 102.8  + hf-xet==1.2.0
# #8 102.8  + httpcore==1.0.9
# #8 102.8  + httptools==0.7.1
# #8 102.8  + httpx==0.28.1
# #8 102.8  + httpx-sse==0.4.3
# #8 102.8  + huggingface-hub==1.0.1
# #8 102.8  + humanfriendly==10.0
# #8 102.8  + identify==2.6.15
# #8 102.8  + idna==3.11
# #8 102.8  + importlib-metadata==8.7.0
# #8 102.8  + importlib-resources==6.5.2
# #8 102.8  + instructor==1.12.0
# #8 102.8  + jinja2==3.1.6
# #8 102.8  + jiter==0.10.0
# #8 102.8  + jmespath==1.0.1
# #8 102.8  + json-repair==0.25.2
# #8 102.8  + json5==0.12.1
# #8 102.8  + jsonref==1.1.0
# #8 102.8  + jsonschema==4.25.1
# #8 102.8  + jsonschema-specifications==2025.9.1
# #8 102.8  + kubernetes==34.1.0
# #8 102.8  + lance-namespace==0.0.20
# #8 102.8  + lance-namespace-urllib3-client==0.0.20
# #8 102.8  + lancedb==0.25.2
# #8 102.8  + litellm==1.79.1
# #8 102.8  + lxml==6.0.2
# #8 102.8  + markdown-it-py==4.0.0
# #8 102.8  + markupsafe==3.0.3
# #8 102.8  + mcp==1.20.0
# #8 102.8  + mdurl==0.1.2
# #8 102.8  + mmh3==5.2.0
# #8 102.8  + mpmath==1.3.0
# #8 102.8  + multidict==6.7.0
# #8 102.8  + nodeenv==1.9.1
# #8 102.8  + numpy==2.3.4
# #8 102.8  + oauthlib==3.3.1
# #8 102.8  + onnxruntime==1.23.2
# #8 102.8  + openai==1.109.1
# #8 102.8  + openpyxl==3.1.5
# #8 102.8  + opentelemetry-api==1.38.0
# #8 102.8  + opentelemetry-exporter-otlp-proto-common==1.38.0
# #8 102.8  + opentelemetry-exporter-otlp-proto-grpc==1.38.0
# #8 102.8  + opentelemetry-exporter-otlp-proto-http==1.38.0
# #8 102.8  + opentelemetry-instrumentation==0.59b0
# #8 102.8  + opentelemetry-instrumentation-threading==0.59b0
# #8 102.8  + opentelemetry-proto==1.38.0
# #8 102.8  + opentelemetry-sdk==1.38.0
# #8 102.8  + opentelemetry-semantic-conventions==0.59b0
# #8 102.8  + orjson==3.11.4
# #8 102.8  + overrides==7.7.0
# #8 102.8  + packaging==25.0
# #8 102.8  + pdfminer-six==20250506
# #8 102.8  + pdfplumber==0.11.7
# #8 102.8  + pillow==12.0.0
# #8 102.8  + pip==25.3
# #8 102.8  + platformdirs==4.5.0
# #8 102.8  + portalocker==2.7.0
# #8 102.8  + posthog==5.4.0
# #8 102.8  + pre-commit==4.3.0
# #8 102.8  + propcache==0.4.1
# #8 102.8  + protobuf==6.33.0
# #8 102.8  + pyarrow==22.0.0
# #8 102.8  + pyasn1==0.6.1
# #8 102.8  + pyasn1-modules==0.4.2
# #8 102.8  + pybase64==1.4.2
# #8 102.8  + pycparser==2.23
# #8 102.8  + pydantic==2.12.3
# #8 102.8  + pydantic-core==2.41.4
# #8 102.8  + pydantic-settings==2.11.0
# #8 102.8  + pygments==2.19.2
# #8 102.8  + pyjwt==2.10.1
# #8 102.8  + pylance==0.39.0
# #8 102.8  + pypdf==6.1.3
# #8 102.8  + pypdfium2==5.0.0
# #8 102.8  + pypika==0.48.9
# #8 102.8  + pyproject-hooks==1.2.0
# #8 102.8  + python-dateutil==2.9.0.post0
# #8 102.8  + python-docx==1.2.0
# #8 102.8  + python-dotenv==1.2.1
# #8 102.8  + python-multipart==0.0.20
# #8 102.8  + pytube==15.0.0
# #8 102.8  + pyyaml==6.0.3
# #8 102.8  + referencing==0.37.0
# #8 102.8  + regex==2025.11.3
# #8 102.8  + requests==2.32.5
# #8 102.8  + requests-oauthlib==2.0.0
# #8 102.8  + rich==14.2.0
# #8 102.8  + rpds-py==0.28.0
# #8 102.8  + rsa==4.9.1
# #8 102.8  + s3transfer==0.14.0
# #8 102.8  + shellingham==1.5.4
# #8 102.8  + six==1.17.0
# #8 102.8  + sniffio==1.3.1
# #8 102.8  + soupsieve==2.8
# #8 102.8  + sse-starlette==3.0.3
# #8 102.8  + starlette==0.49.3
# #8 102.8  + strands-agents==1.14.0
# #8 102.8  + sympy==1.14.0
# #8 102.8  + tenacity==9.1.2
# #8 102.8  + tiktoken==0.12.0
# #8 102.8  + tokenizers==0.22.1
# #8 102.8  + tomli==2.3.0
# #8 102.8  + tomli-w==1.2.0
# #8 102.8  + tqdm==4.67.1
# #8 102.8  + typer==0.20.0
# #8 102.8  + typer-slim==0.20.0
# #8 102.8  + typing-extensions==4.15.0
# #8 102.8  + typing-inspection==0.4.2
# #8 102.8  + urllib3==2.3.0
# #8 102.8  + uv==0.9.7
# #8 102.8  + uvicorn==0.38.0
# #8 102.8  + uvloop==0.22.1
# #8 102.8  + virtualenv==20.35.4
# #8 102.8  + watchdog==6.0.0
# #8 102.8  + watchfiles==1.1.1
# #8 102.8  + websocket-client==1.9.0
# #8 102.8  + websockets==15.0.1
# #8 102.8  + wrapt==1.17.3
# #8 102.8  + yarl==1.22.0
# #8 102.8  + youtube-transcript-api==1.2.3
# #8 102.8  + zipp==3.23.0
# #8 DONE 104.5s
#
# #9 [5/5] COPY app/ ./app/
# #9 DONE 1.6s
#
# #10 exporting to image
# #10 exporting layers
# #10 exporting layers 55.5s done
# #10 exporting manifest sha256:6b030d78c96f390cd13bc49140e28248f7af553ecb8565add4eaa9448e35ad98 0.0s done
# #10 exporting config sha256:68d74871222821cb66685109c0bbe5bdb0adcd702ba19dcfa6c112fdc4957d4c 0.0s done
# #10 exporting attestation manifest sha256:ae29142cc6b123921f3decbd4d91362317895582c19f6dad1ef1e2aad571e986 0.0s done
# #10 exporting manifest list sha256:4e5787b24fef0bfab3639aad1c50b979d854976733b1f65cac4cc17b9e5f35e6
# #10 exporting manifest list sha256:4e5787b24fef0bfab3639aad1c50b979d854976733b1f65cac4cc17b9e5f35e6 0.0s done
# #10 naming to 792560738609.dkr.ecr.us-east-1.amazonaws.com/hemz_agents_repo:latest done
# #10 DONE 55.8s
#
# View build details: docker-desktop://dashboard/build/desktop-linux/desktop-linux/mc2hd5xzzln1u68oqc8l4tx58

# %%
# push the image to repository
# !docker push $processing_repository_uri
# Out:
# The push refers to repository [792560738609.dkr.ecr.us-east-1.amazonaws.com/hemz_agents_repo]
# f0848f197f70: Waiting
# e773b80e62e3: Waiting
# 21b7accdc53f: Waiting
# b34e631a6ef2: Waiting
# 3d410fb3ba62: Waiting
# 7e2977d16f73: Waiting
# 8ae0a1c830fe: Waiting
# 4e268f2242be: Waiting
# 5ae4bd10d370: Waiting
# 7d7f9df211d3: Waiting
# e773b80e62e3: Waiting
# 21b7accdc53f: Waiting
# b34e631a6ef2: Waiting
# 3d410fb3ba62: Waiting
# 7e2977d16f73: Waiting
# 8ae0a1c830fe: Waiting
# 4e268f2242be: Waiting
# 5ae4bd10d370: Waiting
# 7d7f9df211d3: Waiting
# f0848f197f70: Waiting
# f0848f197f70: Waiting
# e773b80e62e3: Waiting
# 21b7accdc53f: Waiting
# b34e631a6ef2: Waiting
# 3d410fb3ba62: Waiting
# 7e2977d16f73: Waiting
# 8ae0a1c830fe: Waiting
# 4e268f2242be: Waiting
# 5ae4bd10d370: Waiting
# 7d7f9df211d3: Waiting
# 8ae0a1c830fe: Waiting
# 4e268f2242be: Waiting
# 5ae4bd10d370: Waiting
# 7d7f9df211d3: Waiting
# f0848f197f70: Waiting
# e773b80e62e3: Waiting
# 21b7accdc53f: Waiting
# b34e631a6ef2: Waiting
# 3d410fb3ba62: Waiting
# 7e2977d16f73: Waiting
# 7d7f9df211d3: Waiting
# f0848f197f70: Waiting
# e773b80e62e3: Waiting
# 21b7accdc53f: Waiting
# b34e631a6ef2: Waiting
# 3d410fb3ba62: Waiting
# 7e2977d16f73: Waiting
# 8ae0a1c830fe: Waiting
# 4e268f2242be: Waiting
# 5ae4bd10d370: Waiting
# 4e268f2242be: Waiting
# 5ae4bd10d370: Waiting
# 7d7f9df211d3: Waiting
# f0848f197f70: Waiting
# e773b80e62e3: Waiting
# 21b7accdc53f: Waiting
# b34e631a6ef2: Waiting
# 3d410fb3ba62: Waiting
# 7e2977d16f73: Waiting
# 8ae0a1c830fe: Waiting
# 3d410fb3ba62: Waiting
# 7e2977d16f73: Waiting
# 8ae0a1c830fe: Waiting
# 4e268f2242be: Waiting
# 5ae4bd10d370: Waiting
# 7d7f9df211d3: Waiting
# f0848f197f70: Waiting
# e773b80e62e3: Waiting
# 21b7accdc53f: Waiting
# b34e631a6ef2: Waiting
# 7d7f9df211d3: Waiting
# f0848f197f70: Waiting
# e773b80e62e3: Waiting
# 21b7accdc53f: Waiting
# b34e631a6ef2: Waiting
# 3d410fb3ba62: Waiting
# 7e2977d16f73: Waiting
# 8ae0a1c830fe: Waiting
# 4e268f2242be: Waiting
# 5ae4bd10d370: Waiting
# 8ae0a1c830fe: Waiting
# 4e268f2242be: Waiting
# 5ae4bd10d370: Waiting
# 7d7f9df211d3: Waiting
# f0848f197f70: Waiting
# e773b80e62e3: Waiting
# 21b7accdc53f: Waiting
# b34e631a6ef2: Waiting
# 3d410fb3ba62: Waiting
# 7e2977d16f73: Waiting
# 8ae0a1c830fe: Waiting
# 4e268f2242be: Waiting
# 5ae4bd10d370: Waiting
# 7d7f9df211d3: Waiting
# f0848f197f70: Waiting
# e773b80e62e3: Waiting
# 21b7accdc53f: Waiting
# b34e631a6ef2: Waiting
# 3d410fb3ba62: Waiting
# 7e2977d16f73: Waiting
# 4e268f2242be: Waiting
# 5ae4bd10d370: Waiting
# 7d7f9df211d3: Waiting
# f0848f197f70: Waiting
# e773b80e62e3: Waiting
# 21b7accdc53f: Waiting
# b34e631a6ef2: Waiting
# 3d410fb3ba62: Waiting
# 7e2977d16f73: Waiting
# 8ae0a1c830fe: Waiting
# 7e2977d16f73: Waiting
# 8ae0a1c830fe: Waiting
# 4e268f2242be: Waiting
# 5ae4bd10d370: Waiting
# 7d7f9df211d3: Waiting
# f0848f197f70: Waiting
# e773b80e62e3: Waiting
# 21b7accdc53f: Waiting
# b34e631a6ef2: Waiting
# 3d410fb3ba62: Waiting
# f0848f197f70: Waiting
# e773b80e62e3: Waiting
# 21b7accdc53f: Waiting
# b34e631a6ef2: Waiting
# 3d410fb3ba62: Waiting
# 7e2977d16f73: Waiting
# 8ae0a1c830fe: Waiting
# 4e268f2242be: Waiting
# 5ae4bd10d370: Waiting
# 7d7f9df211d3: Waiting
# e773b80e62e3: Waiting
# 21b7accdc53f: Waiting
# b34e631a6ef2: Waiting
# 3d410fb3ba62: Waiting
# 7e2977d16f73: Waiting
# 8ae0a1c830fe: Waiting
# 4e268f2242be: Waiting
# 5ae4bd10d370: Waiting
# 7d7f9df211d3: Waiting
# f0848f197f70: Waiting
# e773b80e62e3: Waiting
# 21b7accdc53f: Waiting
# b34e631a6ef2: Waiting
# 3d410fb3ba62: Waiting
# 7e2977d16f73: Waiting
# 8ae0a1c830fe: Waiting
# 4e268f2242be: Waiting
# 5ae4bd10d370: Waiting
# 7d7f9df211d3: Waiting
# f0848f197f70: Waiting
# 7d7f9df211d3: Waiting
# f0848f197f70: Waiting
# e773b80e62e3: Waiting
# 21b7accdc53f: Waiting
# b34e631a6ef2: Layer already exists
# 3d410fb3ba62: Waiting
# 7e2977d16f73: Waiting
# 8ae0a1c830fe: Waiting
# 4e268f2242be: Waiting
# 5ae4bd10d370: Waiting
# f0848f197f70: Layer already exists
# e773b80e62e3: Layer already exists
# 21b7accdc53f: Layer already exists
# 3d410fb3ba62: Layer already exists
# 7e2977d16f73: Waiting
# 8ae0a1c830fe: Waiting
# 4e268f2242be: Waiting
# 5ae4bd10d370: Waiting
# 7d7f9df211d3: Waiting
# 7d7f9df211d3: Waiting
# 7e2977d16f73: Waiting
# 8ae0a1c830fe: Waiting
# 4e268f2242be: Waiting
# 5ae4bd10d370: Waiting
# 7e2977d16f73: Waiting
# 8ae0a1c830fe: Waiting
# 4e268f2242be: Waiting
# 5ae4bd10d370: Waiting
# 7d7f9df211d3: Waiting
# 7e2977d16f73: Waiting
# 8ae0a1c830fe: Waiting
# 4e268f2242be: Waiting
# 5ae4bd10d370: Waiting
# 7d7f9df211d3: Waiting
# 7d7f9df211d3: Pushed
# 7e2977d16f73: Pushed
# 8ae0a1c830fe: Pushed
# 4e268f2242be: Pushed
# 5ae4bd10d370: Pushed
# latest: digest: sha256:4e5787b24fef0bfab3639aad1c50b979d854976733b1f65cac4cc17b9e5f35e6 size: 856

# %%
# Verify the image
# !aws ecr describe-images --repository-name {ecr_repository} --region {region}
# Out:
# {
#     "imageDetails": [
#         {
#             "registryId": "792560738609",
#             "repositoryName": "hemz_agents_repo",
#             "imageDigest": "sha256:9dda8d78aedbb5f7b7af21b358b96923356af0cdc80e4fadd3451a4e38de28a2",
#             "imageSizeInBytes": 360701515,
#             "imagePushedAt": "2025-11-03T23:20:27.400000+05:30",
#             "imageManifestMediaType": "application/vnd.oci.image.index.v1+json",
#             "lastRecordedPullTime": "2025-11-03T23:23:36.886000+05:30"
#         },
#         {
#             "registryId": "792560738609",
#             "repositoryName": "hemz_agents_repo",
#             "imageDigest": "sha256:a5a866c4656842a5420ff9707e1431961276c8b10ffbacb6b2e14785d0e0aa38",
#             "imageSizeInBytes": 1429,
#             "imagePushedAt": "2025-11-03T23:20:26.510000+05:30",
#             "imageManifestMediaType": "application/vnd.oci.image.manifest.v1+json",
#             "artifactMediaType": "application/vnd.oci.image.config.v1+json"
#         },
#         {
#             "registryId": "792560738609",
#             "repositoryName": "hemz_agents_repo",
#             "imageDigest": "sha256:6b030d78c96f390cd13bc49140e28248f7af553ecb8565add4eaa9448e35ad98",
#             "imageSizeInBytes": 371148898,
#             "imagePushedAt": "2025-11-04T16:42:29.929000+05:30",
#             "imageManifestMediaType": "application/vnd.oci.image.manifest.v1+json",
#             "artifactMediaType": "application/vnd.oci.image.config.v1+json"
#         },
#         {
#             "registryId": "792560738609",
#             "repositoryName": "hemz_agents_repo",
#             "imageDigest": "sha256:d53e8071c7798ce4fc70e017bef1313460a97406255177ec5ebc5f9c9e200786",
#             "imageSizeInBytes": 360701515,
#             "imagePushedAt": "2025-11-03T23:20:25.975000+05:30",
#             "imageManifestMediaType": "application/vnd.oci.image.manifest.v1+json",
#             "artifactMediaType": "application/vnd.oci.image.config.v1+json",
#             "lastRecordedPullTime": "2025-11-03T23:23:37.042000+05:30"
#         },
#         {
#             "registryId": "792560738609",
#             "repositoryName": "hemz_agents_repo",
#             "imageDigest": "sha256:ae29142cc6b123921f3decbd4d91362317895582c19f6dad1ef1e2aad571e986",
#             "imageSizeInBytes": 1429,
#             "imagePushedAt": "2025-11-04T16:42:30.187000+05:30",
#             "imageManifestMediaType": "application/vnd.oci.image.manifest.v1+json",
#             "artifactMediaType": "application/vnd.oci.image.config.v1+json"
#         },
#         {
#             "registryId": "792560738609",
#             "repositoryName": "hemz_agents_repo",
#             "imageDigest": "sha256:4e5787b24fef0bfab3639aad1c50b979d854976733b1f65cac4cc17b9e5f35e6",
#             "imageTags": [
#                 "latest"
#             ],
#             "imageSizeInBytes": 371148898,
#             "imagePushedAt": "2025-11-04T16:42:31.105000+05:30",
#             "imageManifestMediaType": "application/vnd.oci.image.index.v1+json"
#         }
#     ]
# }
